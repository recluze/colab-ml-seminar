# %% [markdown]
# # Expressions
#
# Let's start with some basic expressions

# %%
17

# %%
-2 + 15

# %%
-2 - 1

# %%
-2 -     -1

# %%
14 / 3

# %%
1 / 2

# %%
1 % 2

# %%
15 % 2

# %%
1 / 2.0

# %%
type(1)

# %%
type(1/2)   # Different in Python 2

# %%
1/2.0 + 1/4.0

# %%
2.1 + 5.3

# %%
2 + 2 * 2

# %%
(2 + 2) * 2 # overriding precedence

# %% [markdown]
# See more about precedence here: https://docs.python.org/3/reference/expressions.html#operator-precedence

# %%
3 < 4        # conditional expression

# %%
3 == 4

# %%
3 == 3

# %%
3 = 3   # ignore the *details* of the error for now. Notice that this works in C/C++ but not here

# %%
3 > 4

# %%
3 >= 3

# %%
2 <= 1

# %% [markdown]
# ## Other types of expressions

# %%
'abc'

# %%
"xyz"

# %%
"""This is called a multi-line string.     
It can, obviously, span multiple lines! """

# %%
"ab" + "cd"

# %%
type("ab")

# %%
"a-" * 3

# %%
True

# %%
False

# %%
True and True

# %%
True and False

# %%
False and True

# %%
False and False

# %%
True or True

# %%
True or False

# %%
False or True

# %%
False or False

# %%
True or False and False or False

# %%
(True or False) and (False or False)

# %% [markdown]
# # Call Expressions

# %%
max(7, 9)

# %%
max(2+25, 9)

# %%
pow(3, 2)

# %%
max( min(1, -2) , min( pow(3, 5) , -4)    )
